# %% [markdown]
# # EPF (Exceedance Probabilistic Forecasting)
# Based on the book "***Deep Learning for Time Series Data CookBook***", by Victor Cerqueira and Luiz Roque (chapter 7)
#
# "Exceedance probability forecasting is the process of predicting the probability that a time series will exceed a critical threshold in a future period." (p. 165)

# %%
# %pip install numpy==1.26.2 \
             pandas==2.1.3 \
             scikit-learn==1.3.2 \
             torch==2.1.1 \
             pytorch-lightning==2.1.2 \
             pytorch-forecasting==1.0.0 \
             statsforecast==1.6.0
# Out:
# ...
#      ---------------------------------------- 0.0/15.7 MB ? eta -:--:--
#       --------------------------------------- 0.3/15.7 MB ? eta -:--:--
#       --------------------------------------- 0.3/15.7 MB ? eta -:--:--
#      - ------------------------------------- 0.5/15.7 MB 912.6 kB/s eta 0:00:17
#      - ------------------------------------- 0.5/15.7 MB 912.6 kB/s eta 0:00:17
#      - ------------------------------------- 0.5/15.7 MB 912.6 kB/s eta 0:00:17
#      - ------------------------------------- 0.8/15.7 MB 610.6 kB/s eta 0:00:25
#      -- ------------------------------------ 1.0/15.7 MB 697.5 kB/s eta 0:00:21
#      -- ------------------------------------ 1.0/15.7 MB 697.5 kB/s eta 0:00:21
#      --- ----------------------------------- 1.3/15.7 MB 690.9 kB/s eta 0:00:21
#      --- ----------------------------------- 1.3/15.7 MB 690.9 kB/s eta 0:00:21
#      --- ----------------------------------- 1.6/15.7 MB 662.7 kB/s eta 0:00:22
# ...

# %% [markdown]
# There are more libraries to be installed. We're only kidding by now.

# %%
import pandas as pd
epf_data = pd.read_csv('C:/Users/Miguel/OneDrive/Desktop/Libellula/predictive_model/financial_tools/financial_tools_datset.csv',
                        parse_dates=['Date'],
                        index_col='Date')
epf_data
# Out:
#              Price    Open    High     Low Change %  short_mavg  long_mavg  \
# Date
# 2026-02-11  1.1871  1.1895  1.1928  1.1833   -0.20%    1.187100   1.187100
# 2026-02-10  1.1895  1.1913  1.1929  1.1887   -0.17%    1.188300   1.188300
# 2026-02-09  1.1915  1.1817  1.1927  1.1809    0.74%    1.189367   1.189367
# 2026-02-08  1.1827  1.1814  1.1828  1.1810    0.08%    1.187700   1.187700
# 2026-02-06  1.1817  1.1778  1.1827  1.1765    0.34%    1.186500   1.186500
# ...            ...     ...     ...     ...      ...         ...        ...
# 2020-02-17  1.0834  1.0832  1.0852  1.0821    0.04%    1.086880   1.093953
# 2020-02-14  1.0830  1.0841  1.0862  1.0827   -0.09%    1.084930   1.093937
# 2020-02-13  1.0840  1.0874  1.0890  1.0833   -0.29%    1.083350   1.093950
# 2020-02-12  1.0871  1.0916  1.0926  1.0865   -0.39%    1.083270   1.094078
# 2020-02-11  1.0914  1.0911  1.0926  1.0890    0.05%    1.083620   1.094205
#
# ...

# %%
def setup(self, stage=None):

    # 1️⃣ Pré-processamento original
    self.preprocess_data()

    # 2️⃣ Criar target binário para EPF (rompimento de drawdown)
    # Assume que já existe uma coluna 'future_drawdown'
    self.data["target"] = (
        self.data["future_drawdown"] > self.theta
    ).astype(int)

    # 3️⃣ Split temporal
    train_indices, val_indices, test_indices = self.split_data()

    train_df = self.data.loc[self.data["time_index"].isin(train_indices)]
    val_df   = self.data.loc[self.data["time_index"].isin(val_indices)]
    test_df  = self.data.loc[self.data["time_index"].isin(test_indices)]

    # 4️⃣ Remover colunas desnecessárias
    train_df = train_df.drop("Incoming Solar", axis=1, errors="ignore")
    val_df   = val_df.drop("Incoming Solar", axis=1, errors="ignore")
    test_df  = test_df.drop("Incoming Solar", axis=1, errors="ignore")

    # 5️⃣ Criar TimeSeriesDataSet (sem escalar target binário)
    self.training = TimeSeriesDataSet(
        train_df,
        time_idx="time_index",
        target="target",
        group_ids=["group_id"],
        max_encoder_length=self.n_lags,
        max_prediction_length=self.horizon,
        time_varying_unknown_reals=self.feature_names,
        scalers={name: StandardScaler() for name in self.feature_names},
    )

    self.validation = TimeSeriesDataSet.from_dataset(self.training, val_df)
    self.test       = TimeSeriesDataSet.from_dataset(self.training, test_df)
    self.predict_set = TimeSeriesDataSet.from_dataset(
        self.training, self.data, predict=True
    )
